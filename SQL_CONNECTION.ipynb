# %%
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt 
import seaborn as sns 
from sqlalchemy import create_engine ,text

# %%
engine=create_engine(
"mysql+pymysql://property:propertyy@localhost:3306/propertydb",
echo=True   
)

# %%
with engine.connect()as conn:
    result=conn.execute(text("SELECT DATABASE();"))
    print("CONNECT TO :",result.fetchone())
# Out:
# 2026-04-17 17:26:54,882 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-17 17:26:54,884 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-17 17:26:54,894 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-17 17:26:54,898 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-17 17:26:54,903 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-17 17:26:54,905 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-17 17:26:54,913 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-17 17:26:54,916 INFO sqlalchemy.engine.Engine SELECT DATABASE();
# 2026-04-17 17:26:54,919 INFO sqlalchemy.engine.Engine [generated in 0.00629s] {}
# CONNECT TO : ('propertydb',)
# 2026-04-17 17:26:54,923 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
df=pd.read_csv(r"C:\Users\rohit\OneDrive\Desktop\PROJECT\House Price India.csv")

# %%
df.to_sql("PROPERTY_DATA",con=engine,if_exists='replace',index=False)
# Out:
# 2026-04-17 17:32:41,918 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-17 17:32:41,935 INFO sqlalchemy.engine.Engine DESCRIBE `propertydb`.`PROPERTY_DATA`
# 2026-04-17 17:32:41,938 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-17 17:32:41,956 INFO sqlalchemy.engine.Engine
# CREATE TABLE `PROPERTY_DATA` (
# 	id BIGINT,
# 	`Date` BIGINT,
# 	`number of bedrooms` BIGINT,
# 	`number of bathrooms` FLOAT(53),
# 	`living area` BIGINT,
# 	`lot area` BIGINT,
# 	`number of floors` FLOAT(53),
# 	`waterfront present` BIGINT,
# 	`number of views` BIGINT,
# 	`condition of the house` BIGINT,
# 	`grade of the house` BIGINT,
# 	`Area of the house(excluding basement)` BIGINT,
# 	`Area of the basement` BIGINT,
# 	`Built Year` BIGINT,
# 	`Renovation Year` BIGINT,
# 	`Postal Code` BIGINT,
# 	`Lattitude` FLOAT(53),
# 	`Longitude` FLOAT(53),
# 	living_area_renov BIGINT,
# 	lot_area_renov BIGINT,
# 	`Number of schools nearby` BIGINT,
# 	`Distance from the airport` BIGINT,
# 	`Price` BIGINT
# ...
